# %% [markdown]
# # <font color='FF6F1F'>Case ANAC</font>
#
# ## <font color='FF6F1F'>Análise Exploratória de Dados</font>

# %% [markdown]
# # Tabela de conteúdo
#
# [1. Informação básica](#1.-Informação-básica)
#
# [2. Bibliotecas](#2.-Bibliotecas)
#
# [3. Dados](#3.-Dados)
#
# [4. Estatística básica](#4.-Estatística-básica)
#
# [5. Distribuições](#5.-Distribuições)
#
# [6. Visualizações](#6.-Visualizações)

# %% [markdown]
# ## 1. Informação básica
# [Retorna à Tabela de conteúdo](#Tabela-de-conteúdo)

# %% [markdown]
# **Fonte:** https://www.anac.gov.br/assuntos/setor-regulado/empresas/envio-de-informacoes/microdados
#
# **Período:** dezembro de 2020
#
# **Contexto:** A base de dados refere-se a _Etapa Combinada (On flight origin and destination - OFOD)_
#
# * As _etapas combinadas_ identificam os pares de origem, onde ocorreu o embarque do objeto de transporte, e destino, onde ocorreu o desembarque do objeto de transporte, independentemente da existência de aeródromos intermediários, atendidos por determinado voo. É a etapa de voo vista com foco no objeto de transporte (pessoas e/ou cargas), com base no embarque e no desembarque nos aeródromos relacionados. Os dados estatísticos da etapa combinada informam a origem e destino dos passageiros e cargas transportadas no voo, independentemente das escalas realizadas.
#
# **Descrição das colunas:**
#
# | Variável | Descrição | Tipo |
# |:---|:---|:---|
# | id_combinada | Código numérido identificador da etapa combinada no sistema. ||
# | id_empresa | Código numérico identificador da empresa no sistema. ||
# | sg_empresa_icao | Sigla ICAO da empresa aérea. Refere-se ao designador da empresa de transporte aéreo obtido junto à OACI (Organização da Aviação Civil Internacional). ||
# | sg_empresa_iata | Sigla IATA da empresa aérea. Refere-se ao designador da empresa de transporte aéreo obtido junto à IATA (Associação Internacional de Transporte Aéreo). ||
# | nm_empresa | Nome da empresa aérea. ||
# | nm_pais | Nome do país da nacionalidade da empresa aérea. ||
# | ds_tipo_empresa | Descrição do tipo de empresa. Refere-se à descrição do tipo de empresa em relação ao serviço realizado. Pode conter as seguintes descrições. Essa variável está em desuso. ||
# | nr_voo | Número do voo. Refere-se ao número atribuído à operação de uma etapa ou de uma série de etapas registradas sob a mesma numeração de voo. ||
# | nr_singular | Singularidade do Voo. Refere-se ao conjunto de caracteres que auxilia na identificação do voo, composto de letras e números escolhidos a critério da própria empresa aérea. ||
# | id_di | Código numérico que referencia ao sistema a variável Dígito Identificador. ||
# | cd_di | Dígito Identificador. Refere-se ao caractere utilizado para identificar o tipo de autorização para cada etapa de voo, assumindo os seguintes valores: 0 - Etapa Regular, 2 - Etapa Extra, 3 - Etapa de Retorno, 4 - Inclusão de Etapa, 6 - Etapa Não Remunerada Sem Transporte de Objetos, 7 - Etapa de Voo de Fretamento, 9 - Etapa de Voo Charter, D - Etapa de Voo Duplicada ||
# | ds_di | Descrição DI. Apresenta a descrição correspondente ao Dígito Identificador apresentado.  ||
# | ds_grupo_di | Descrição do grupo DI ou Tipo de Voo. Refere-se ao agrupamento das classificações de DI em tipos de operações: Regular DIs 0, 4 ou C); Não regular (DIs 1,2,5,7,8,9 ou D); Improdutivo (Demais DIs) ||
# | dt_referencia | Data de Referência. Corresponde à Data Prevista de Início do Voo. ||
# | nr_ano_referencia | Ano de Referência. ||
# | nr_semestre_referencia | Número do semestre de referência. ||
# | nm_semestre_referencia | Nome do semestre de referência. ||
# | nr_trimestre_referencia | Número do trimestre de referência. ||
# | nm_trimestre_referencia | Nome do trimestre de referência. ||
# | nr_mes_referencia | Número do mês de referência. ||
# | nm_mes_referencia | Nome do mês de referência. ||
# | nr_semana_referencia | Número da semana de referência. ||
# | nm_dia_semana_referencia | Nome do dia da semana de referência. ||
# | nr_dia_referencia | Número do dia de referência. ||
# | nr_ano_mes_referencia | Número representando o ano e o mês de referência, no formato AAAAMM. ||
# | id_tipo_linha | Código numérico identificador do tipo de linha no sistema. ||
# | cd_tipo_linha | Caractere que identifica o tipo de linha. O Tipo de Linha identifica o tipo de operação realizada no voo, podendo ser classificado em: N - Doméstica Mista; C - Doméstica Cargueira; I - Internacional Mista; G - Internacional Cargueira ||
# | ds_tipo_linha | Descrição do tipo de linha. ||
# | ds_natureza_tipo_linha | Descrição da natureza referente ao tipo de linha (Internacional/Doméstica). Considera a natureza do voo, não apenas da etapa. ||
# | ds_servico_tipo_linha | Descrição do serviço referente ao tipo de linha (Passageiro/Cargueiro). ||
# | ds_natureza_etapa | Descrição da natureza da etapa de voo (Intenacional/Doméstica). ||
# | hr_partida_real | Horário de partida do voo, apurado pelo critério do calço e descalço. ||
# | dt_partida_real | Data de realização. Refere-se à data completa de decolagem da etapa, apurada pelo critério do calço e descalço. ||
# | nr_ano_partida_real | Número do ano de partida real. ||
# | nr_semestre_partida_real | Número do semestre de partida real. ||
# | nm_semestre_partida_real | Nome do semestre de partida real. ||
# | nr_trimestre_partida_real | Número do trimestre de partida real. ||
# | nm_trimestre_partida_real | Nome do trimestre de partida real. ||
# | nr_mes_partida_real | Número do mês de partida real. ||
# | nm_mes_partida_real | Nome do mês de partida real. ||
# | nr_semana_partida_real | Número da semana de partida real. ||
# | nm_dia_semana_partida_real | Nome do dia da semana de partida real. ||
# | nr_dia_partida_real | Número do dia de partida real. ||
# | nr_ano_mes_partida_real | Número que representa o ano e o mês de partida real, no formato AAAAMM. ||
# | id_aerodromo_origem | Código identificador do aeródromo de origem no sistema. ||
# | sg_icao_origem | Sigla ICAO do aeródromo de origem. ||
# | sg_iata_origem | Sigla IATA do aeródromo de origem. ||
# | nm_aerodromo_origem | Nome do aeródromo de origem. ||
# | nm_municipio_origem | Nome do município de origem. ||
# | sg_uf_origem | Sigla da Unidade Federativa de origem. ||
# | nm_regiao_origem | Nome da região de origem. ||
# | nm_pais_origem | Nome do país de origem. ||
# | nm_continente_origem | Nome do continente de origem. ||
# | nr_etapa | Número da etapa. Indica a sequência do aeródromo de origem entre os aeródromos sob o mesmo número de voo. ||
# | hr_chegada_real | Horário de chegada do voo, apurado pelo critério do calço e descalço. ||
# | dt_chegada_real | Data real de chegada. ||
# | nr_ano_chegada_real | Número do ano de chegada real. ||
# | nr_semestre_chegada_real | Número do semestre de chegada real. ||
# | nm_semestre_chegada_real | Nome do semestre de chegada real. ||
# | nr_trimestre_chegada_real | Número do trimestre de chegada real. ||
# | nm_trimestre_chegada_real | Nome do trimestre de chegada real. ||
# | nr_mes_chegada_real | Número do mês de chegada real. ||
# | nm_mes_chegada_real | Nome do mês de chegada real. ||
# | nr_semana_chegada_real | Número da semana de chegada real. ||
# | nm_dia_semana_chegada_real | Nome do dia da semana de chegada real. ||
# | nr_dia_chegada_real | Número do dia de chegada real. ||
# | nr_ano_mes_chegada_real | Número que representa o ano e o mês de chegada real, no formato AAAAMM. ||
# | id_aerodromo_destino | Código identificador do aeródromo de destino no sistema. ||
# | sg_icao_destino | Sigla ICAO do aeródromo de destino. ||
# | sg_iata_destino | Sigla IATA do aeródromo de destino. ||
# | nm_aerodromo_destino | Nome do aeródromo de destino. ||
# | nm_municipio_destino | Nome do município de destino. ||
# | sg_uf_destino | Sigla da Unidade Federativa de destino. ||
# | nm_regiao_destino | Nome da região de destino. ||
# | nm_pais_destino | Nome do país de destino. ||
# | nm_continente_destino | Nome do continente de destino. ||
# | nr_escala_destino | Sequência de escala de destino. É o número correspondente ao aeródromo de destino da etapa, considerando a numeração sequencial dos aeródromos percorridos sob um mesmo voo. ||
# | cd_cotran | Caractere que representa o Cotran (Código de Transporte). O Cotran é utilizado para informar o tipo de desembarque realizado pelo objeto de transporte (passageiro, carga ou correio), informando sobre a realização ou não de conexões. Ele pode assumir os seguintes valores: N -Desembarque; D -Trânsito Doméstico; I -Trânsito Internacional ||
# | ds_cotran | Descrição do Cotran (Código de Transporte). ||
# | nr_passag_pagos | Número de passageiros que ocupam assentos comercializados ao público e que geram receita, com a compra de assentos, para a empresa de transporte aéreo. ||
# | nr_passag_gratis | Número de passageiros que ocupam assentos comercializados ao público mas não geram receita, com a compra de assentos, para a empresa de transporte aéreo. ||
# | kg_bagagem_livre | Bagagem franqueada. É toda bagagem que não é considerada como excesso, expressa em quilogramas. ||
# | kg_bagagem_excesso | Excesso de bagagem. É a quantidade total de bagagem que excede o limite de peso acordado entre a empresa aérea e o passageiro (adquirido antes ou depois da compra do bilhete), verificada no momento do despacho, expressa em quilogramas. ||
# | kg_carga_paga | Carga paga. É a quantidade total, expressa em quilogramas, de todos os bens que tenham sido transportados na aeronave, exceto correio e bagagem, e tenham gerado receita direta ou indireta para a empresa aérea. ||
# | kg_carga_gratis | Quantidade total, expressa em quilogramas, de todos os bens que tenham sido transportados na aeronave, exceto correio e bagagem, e não tenha gerado receitas diretas ou indiretas para a empresa aérea. ||
# | kg_correio | Quantidade, expressa em quilogramas, de objetos transportados para atender aos operadores designados oficialmente pelo país para operar serviços postais e cumprir com as obrigações associadas decorrentes dos Atos da Universal Postal Union (UPU). ||
# | id_arquivo | Código identificador do arquivo de dados enviado ao sistema. ||
# | nm_arquivo | Nome do arquivo enviado ao sistema. ||
# | nr_linha | Número da linha do arquivo na qual estão contidos os dados de cada etapa básica. ||
# | dt_sistema | Data em que as informações foram registradas no sistema. ||
#
# **Maiores informações:** https://www.anac.gov.br/assuntos/setor-regulado/empresas/envio-de-informacoes/descricao-de-variaveis

# %% [markdown]
# ## 2. Bibliotecas
# [Retorna à Tabela de conteúdo](#Tabela-de-conteúdo)

# %%
import pandas as pd # dataframe
import numpy as np # numeric
import seaborn as sns # graph
from matplotlib import pyplot as plt # plot

# %% [markdown]
# ## 3. Dados
# [Retorna à Tabela de conteúdo](#Tabela-de-conteúdo)

# %%
# exibir todas as colunas
pd.set_option('max_columns', None)

# %%
df = pd.read_csv('combinada2020-12.txt', sep=';', encoding='latin1', engine='python')

# %%
df.sample(5)
# Out:
#        id_combinada  id_empresa sg_empresa_icao sg_empresa_iata  \
# 48740      61948908     1001093             TAM              JJ
# 34232      61932991     1000909             AZU              AD
# 21203      61919965     1000909             AZU              AD
# 45971      61946144     1001093             TAM              JJ
# 47483      61947652     1001093             TAM              JJ
#
#                                nm_empresa nm_pais           ds_tipo_empresa  \
# 48740              TAM LINHAS AÉREAS S.A.  BRASIL  TRANSPORTE AÉREO REGULAR
# 34232  AZUL LINHAS AÉREAS BRASILEIRAS S/A  BRASIL  TRANSPORTE AÉREO REGULAR
# 21203  AZUL LINHAS AÉREAS BRASILEIRAS S/A  BRASIL  TRANSPORTE AÉREO REGULAR
# 45971              TAM LINHAS AÉREAS S.A.  BRASIL  TRANSPORTE AÉREO REGULAR
# 47483              TAM LINHAS AÉREAS S.A.  BRASIL  TRANSPORTE AÉREO REGULAR
#
#        nr_voo nr_singular  id_di cd_di                       ds_di  \
# 48740    3308         999      2     0  REGULAR PREVISTO EM HOTRAN
# 34232    4073         236      2     0  REGULAR PREVISTO EM HOTRAN
# 21203    4427         236      2     0  REGULAR PREVISTO EM HOTRAN
# 45971    3216         999      2     0  REGULAR PREVISTO EM HOTRAN
# 47483    3344         999      2     0  REGULAR PREVISTO EM HOTRAN
#
#       ds_grupo_di dt_referencia  nr_ano_referencia  nr_semestre_referencia  \
# 48740     REGULAR    2020-12-02               2020                       2
# 34232     REGULAR    2020-12-26               2020                       2
# 21203     REGULAR    2020-12-14               2020                       2
# 45971     REGULAR    2020-12-24               2020                       2
# 47483     REGULAR    2020-12-23               2020                       2
#
#       nm_semestre_referencia  nr_trimestre_referencia nm_trimestre_referencia  \
# 48740            2º SEMESTRE                        4            4º TRIMESTRE
# 34232            2º SEMESTRE                        4            4º TRIMESTRE
# 21203            2º SEMESTRE                        4            4º TRIMESTRE
# 45971            2º SEMESTRE                        4            4º TRIMESTRE
# 47483            2º SEMESTRE                        4            4º TRIMESTRE
#
#        nr_mes_referencia nm_mes_referencia  nr_semana_referencia  \
# 48740                 12          DEZEMBRO                    49
# 34232                 12          DEZEMBRO                    52
# 21203                 12          DEZEMBRO                    51
# 45971                 12          DEZEMBRO                    52
# 47483                 12          DEZEMBRO                    52
#
#       nm_dia_semana_referencia  nr_dia_referencia  nr_ano_mes_referencia  \
# 48740             QUARTA-FEIRA                  2                 202012
# 34232                   SÁBADO                 26                 202012
# 21203            SEGUNDA-FEIRA                 14                 202012
# 45971             QUINTA-FEIRA                 24                 202012
# 47483             QUARTA-FEIRA                 23                 202012
#
#        id_tipo_linha cd_tipo_linha    ds_tipo_linha ds_natureza_tipo_linha  \
# 48740              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 34232              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 21203              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 45971              1             N  DOMÉSTICA MISTA              DOMÉSTICA
# 47483              1             N  DOMÉSTICA MISTA              DOMÉSTICA
#
#       ds_servico_tipo_linha ds_natureza_etapa hr_partida_real dt_partida_real  \
# 48740            PASSAGEIRO         DOMÉSTICA        23:42:00      2020-12-02
# 34232            PASSAGEIRO         DOMÉSTICA        10:58:00      2020-12-26
# 21203            PASSAGEIRO         DOMÉSTICA        05:58:00      2020-12-14
# 45971            PASSAGEIRO         DOMÉSTICA        17:50:00      2020-12-24
# 47483            PASSAGEIRO         DOMÉSTICA        08:13:00      2020-12-23
#
#        nr_ano_partida_real  nr_semestre_partida_real nm_semestre_partida_real  \
# 48740               2020.0                       2.0              2º SEMESTRE
# 34232               2020.0                       2.0              2º SEMESTRE
# 21203               2020.0                       2.0              2º SEMESTRE
# 45971               2020.0                       2.0              2º SEMESTRE
# 47483               2020.0                       2.0              2º SEMESTRE
#
#        nr_trimestre_partida_real nm_trimestre_partida_real  \
# 48740                        4.0              4º TRIMESTRE
# 34232                        4.0              4º TRIMESTRE
# 21203                        4.0              4º TRIMESTRE
# 45971                        4.0              4º TRIMESTRE
# 47483                        4.0              4º TRIMESTRE
#
#        nr_mes_partida_real nm_mes_partida_real  nr_semana_partida_real  \
# 48740                 12.0            DEZEMBRO                    49.0
# 34232                 12.0            DEZEMBRO                    52.0
# 21203                 12.0            DEZEMBRO                    51.0
# 45971                 12.0            DEZEMBRO                    52.0
# 47483                 12.0            DEZEMBRO                    52.0
#
#       nm_dia_semana_partida_real  nr_dia_partida_real  \
# 48740               QUARTA-FEIRA                  2.0
# 34232                     SÁBADO                 26.0
# 21203              SEGUNDA-FEIRA                 14.0
# 45971               QUINTA-FEIRA                 24.0
# 47483               QUARTA-FEIRA                 23.0
#
#        nr_ano_mes_partida_real  id_aerodromo_origem sg_icao_origem  \
# 48740                 202012.0                  301           SBGR
# 34232                 202012.0                  160           SBKG
# 21203                 202012.0                  565           SBPL
# 45971                 202012.0                  588           SBPA
# 47483                 202012.0                  301           SBGR
#
#       sg_iata_origem                          nm_aerodromo_origem  \
# 48740            GRU  GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO
# 34232            CPV                     PRESIDENTE JOÃO SUASSUNA
# 21203            PNZ                          SENADOR NILO COELHO
# 45971            POA                                SALGADO FILHO
# 47483            GRU  GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO
#
#       nm_municipio_origem sg_uf_origem nm_regiao_origem nm_pais_origem  \
# 48740           GUARULHOS           SP          SUDESTE         BRASIL
# 34232      CAMPINA GRANDE           PB         NORDESTE         BRASIL
# 21203           PETROLINA           PE         NORDESTE         BRASIL
# 45971        PORTO ALEGRE           RS              SUL         BRASIL
# 47483           GUARULHOS           SP          SUDESTE         BRASIL
#
#       nm_continente_origem  nr_etapa hr_chegada_real dt_chegada_real  \
# 48740       AMÉRICA DO SUL         1        03:11:00      2020-12-03
# 34232       AMÉRICA DO SUL         1        11:33:00      2020-12-26
# 21203       AMÉRICA DO SUL         1        07:06:00      2020-12-14
# 45971       AMÉRICA DO SUL         1        19:15:00      2020-12-24
# 47483       AMÉRICA DO SUL         1        09:07:00      2020-12-23
#
#        nr_ano_chegada_real  nr_semestre_chegada_real nm_semestre_chegada_real  \
# 48740               2020.0                       2.0              2º SEMESTRE
# 34232               2020.0                       2.0              2º SEMESTRE
# 21203               2020.0                       2.0              2º SEMESTRE
# 45971               2020.0                       2.0              2º SEMESTRE
# 47483               2020.0                       2.0              2º SEMESTRE
#
#        nr_trimestre_chegada_real nm_trimestre_chegada_real  \
# 48740                        4.0              4º TRIMESTRE
# 34232                        4.0              4º TRIMESTRE
# 21203                        4.0              4º TRIMESTRE
# 45971                        4.0              4º TRIMESTRE
# 47483                        4.0              4º TRIMESTRE
#
#        nr_mes_chegada_real nm_mes_chegada_real  nr_semana_chegada_real  \
# 48740                 12.0            DEZEMBRO                    49.0
# 34232                 12.0            DEZEMBRO                    52.0
# 21203                 12.0            DEZEMBRO                    51.0
# 45971                 12.0            DEZEMBRO                    52.0
# 47483                 12.0            DEZEMBRO                    52.0
#
#       nm_dia_semana_chegada_real  nr_dia_chegada_real  \
# 48740               QUINTA-FEIRA                  3.0
# 34232                     SÁBADO                 26.0
# 21203              SEGUNDA-FEIRA                 14.0
# 45971               QUINTA-FEIRA                 24.0
# 47483               QUARTA-FEIRA                 23.0
#
#        nr_ano_mes_chegada_real  id_aerodromo_destino sg_icao_destino  \
# 48740                 202012.0                    96            SBBE
# 34232                 202012.0                   618            SBRF
# 21203                 202012.0                   618            SBRF
# 45971                 202012.0                   301            SBGR
# 47483                 202012.0                   624            SBRP
#
#       sg_iata_destino                               nm_aerodromo_destino  \
# 48740             BEL  INTERNACIONAL DE BELÉM/VAL DE CANS/JÚLIO CEZAR...
# 34232             REC                       GUARARAPES - GILBERTO FREYRE
# 21203             REC                       GUARARAPES - GILBERTO FREYRE
# 45971             GRU        GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO
# 47483             RAO                                        LEITE LOPES
#
#       nm_municipio_destino sg_uf_destino nm_regiao_destino nm_pais_destino  \
# 48740                BELÉM            PA             NORTE          BRASIL
# 34232               RECIFE            PE          NORDESTE          BRASIL
# 21203               RECIFE            PE          NORDESTE          BRASIL
# 45971            GUARULHOS            SP           SUDESTE          BRASIL
# 47483       RIBEIRÃO PRETO            SP           SUDESTE          BRASIL
#
#       nm_continente_destino  nr_escala_destino cd_cotran  \
# 48740        AMÉRICA DO SUL                  2         D
# 34232        AMÉRICA DO SUL                  2         N
# 21203        AMÉRICA DO SUL                  2         N
# 45971        AMÉRICA DO SUL                  2         I
# 47483        AMÉRICA DO SUL                  2         N
#
#                    ds_cotran  nr_passag_pagos  nr_passag_gratis  \
# 48740      CONEXÃO DOMÉSTICO              0.0               0.0
# 34232            DESEMBARQUE              2.0               0.0
# 21203            DESEMBARQUE             55.0               3.0
# 45971  CONEXÃO INTERNACIONAL              2.0               0.0
# 47483            DESEMBARQUE            143.0              10.0
#
#        kg_bagagem_livre  kg_bagagem_excesso  kg_carga_paga  kg_carga_gratis  \
# 48740               0.0                 0.0            0.0              0.0
# 34232               0.0                 0.0            0.0              0.0
# 21203             243.0                20.0           31.0              0.0
# 45971              22.0                 0.0            0.0              0.0
# 47483            1077.0                 0.0          141.0              0.0
#
#        kg_correio  id_arquivo     nm_arquivo  nr_linha           dt_sistema
# 48740         0.0       16910  TAM202012.txt    1867.0  2021-01-09 00:24:33
# 34232         0.0       16882  AZU202012.txt   43229.0  2021-01-07 00:24:40
# 21203         0.0       16882  AZU202012.txt   22732.0  2021-01-07 00:24:40
# 45971         0.0       16910  TAM202012.txt   27645.0  2021-01-09 00:24:33
# 47483         0.0       16910  TAM202012.txt   26753.0  2021-01-09 00:24:33

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125763 entries, 0 to 125762
# Data columns (total 90 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id_combinada                125763 non-null  int64
#  1   id_empresa                  125763 non-null  int64
#  2   sg_empresa_icao             125763 non-null  object
#  3   sg_empresa_iata             125750 non-null  object
#  4   nm_empresa                  125763 non-null  object
#  5   nm_pais                     125763 non-null  object
#  6   ds_tipo_empresa             125763 non-null  object
#  7   nr_voo                      125763 non-null  int64
#  8   nr_singular                 123020 non-null  object
#  9   id_di                       125763 non-null  int64
#  10  cd_di                       125763 non-null  object
#  11  ds_di                       125763 non-null  object
#  12  ds_grupo_di                 125763 non-null  object
#  13  dt_referencia               125763 non-null  object
#  14  nr_ano_referencia           125763 non-null  int64
#  15  nr_semestre_referencia      125763 non-null  int64
#  16  nm_semestre_referencia      125763 non-null  object
#  17  nr_trimestre_referencia     125763 non-null  int64
#  18  nm_trimestre_referencia     125763 non-null  object
#  19  nr_mes_referencia           125763 non-null  int64
#  20  nm_mes_referencia           125763 non-null  object
#  21  nr_semana_referencia        125763 non-null  int64
#  22  nm_dia_semana_referencia    125763 non-null  object
#  23  nr_dia_referencia           125763 non-null  int64
#  24  nr_ano_mes_referencia       125763 non-null  int64
#  25  id_tipo_linha               125763 non-null  int64
#  26  cd_tipo_linha               125763 non-null  object
#  27  ds_tipo_linha               125763 non-null  object
#  28  ds_natureza_tipo_linha      125763 non-null  object
#  29  ds_servico_tipo_linha       125763 non-null  object
#  30  ds_natureza_etapa           125763 non-null  object
#  31  hr_partida_real             125763 non-null  object
#  32  dt_partida_real             125763 non-null  object
#  33  nr_ano_partida_real         125762 non-null  float64
#  34  nr_semestre_partida_real    125762 non-null  float64
#  35  nm_semestre_partida_real    125762 non-null  object
#  36  nr_trimestre_partida_real   125762 non-null  float64
#  37  nm_trimestre_partida_real   125762 non-null  object
#  38  nr_mes_partida_real         125762 non-null  float64
#  39  nm_mes_partida_real         125762 non-null  object
#  40  nr_semana_partida_real      125762 non-null  float64
#  41  nm_dia_semana_partida_real  125762 non-null  object
#  42  nr_dia_partida_real         125762 non-null  float64
#  43  nr_ano_mes_partida_real     125762 non-null  float64
#  44  id_aerodromo_origem         125763 non-null  int64
#  45  sg_icao_origem              125763 non-null  object
#  46  sg_iata_origem              125694 non-null  object
#  47  nm_aerodromo_origem         125763 non-null  object
#  48  nm_municipio_origem         125763 non-null  object
#  49  sg_uf_origem                121632 non-null  object
#  50  nm_regiao_origem            121632 non-null  object
#  51  nm_pais_origem              125763 non-null  object
#  52  nm_continente_origem        125763 non-null  object
#  53  nr_etapa                    125763 non-null  int64
#  54  hr_chegada_real             125761 non-null  object
#  55  dt_chegada_real             125763 non-null  object
#  56  nr_ano_chegada_real         125762 non-null  float64
#  57  nr_semestre_chegada_real    125762 non-null  float64
#  58  nm_semestre_chegada_real    125762 non-null  object
#  59  nr_trimestre_chegada_real   125762 non-null  float64
#  60  nm_trimestre_chegada_real   125762 non-null  object
#  61  nr_mes_chegada_real         125762 non-null  float64
#  62  nm_mes_chegada_real         125762 non-null  object
#  63  nr_semana_chegada_real      125762 non-null  float64
#  64  nm_dia_semana_chegada_real  125762 non-null  object
#  65  nr_dia_chegada_real         125762 non-null  float64
#  66  nr_ano_mes_chegada_real     125762 non-null  float64
#  67  id_aerodromo_destino        125763 non-null  int64
#  68  sg_icao_destino             125763 non-null  object
#  69  sg_iata_destino             125684 non-null  object
#  70  nm_aerodromo_destino        125763 non-null  object
#  71  nm_municipio_destino        125763 non-null  object
#  72  sg_uf_destino               121540 non-null  object
#  73  nm_regiao_destino           121540 non-null  object
#  74  nm_pais_destino             125763 non-null  object
#  75  nm_continente_destino       125763 non-null  object
#  76  nr_escala_destino           125763 non-null  int64
#  77  cd_cotran                   120596 non-null  object
#  78  ds_cotran                   120596 non-null  object
#  79  nr_passag_pagos             125613 non-null  float64
#  80  nr_passag_gratis            125613 non-null  float64
#  81  kg_bagagem_livre            125613 non-null  float64
#  82  kg_bagagem_excesso          125613 non-null  float64
#  83  kg_carga_paga               125613 non-null  float64
#  84  kg_carga_gratis             125613 non-null  float64
#  85  kg_correio                  125613 non-null  float64
#  86  id_arquivo                  125763 non-null  int64
#  87  nm_arquivo                  121135 non-null  object
#  88  nr_linha                    121160 non-null  float64
#  89  dt_sistema                  125763 non-null  object
# dtypes: float64(22), int64(17), object(51)
# memory usage: 86.4+ MB

# %%
print(f'O dataframe possui {df.shape[0]} linhas e {df.shape[1]} colunas.')
# Out:
# O dataframe possui 125763 linhas e 90 colunas.

# %%
# dados faltantes
total = df.isnull().sum().sort_values(ascending=False)
porcentagem = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
faltante = pd.concat([total, porcentagem], axis=1, keys=['Total', 'Porcentagem'])
faltante.head(45)
# Out:
#                             Total  Porcentagem
# ds_cotran                    5167     0.041085
# cd_cotran                    5167     0.041085
# nm_arquivo                   4628     0.036799
# nr_linha                     4603     0.036601
# sg_uf_destino                4223     0.033579
# nm_regiao_destino            4223     0.033579
# sg_uf_origem                 4131     0.032847
# nm_regiao_origem             4131     0.032847
# nr_singular                  2743     0.021811
# kg_carga_gratis               150     0.001193
# kg_correio                    150     0.001193
# nr_passag_pagos               150     0.001193
# nr_passag_gratis              150     0.001193
# kg_bagagem_livre              150     0.001193
# kg_bagagem_excesso            150     0.001193
# kg_carga_paga                 150     0.001193
# sg_iata_destino                79     0.000628
# sg_iata_origem                 69     0.000549
# sg_empresa_iata                13     0.000103
# hr_chegada_real                 2     0.000016
# nm_semestre_partida_real        1     0.000008
# nr_trimestre_partida_real       1     0.000008
# nr_semestre_partida_real        1     0.000008
# nr_semestre_chegada_real        1     0.000008
# nm_trimestre_partida_real       1     0.000008
# nr_mes_partida_real             1     0.000008
# nm_mes_partida_real             1     0.000008
# nr_ano_chegada_real             1     0.000008
# nr_ano_mes_partida_real         1     0.000008
# nr_dia_partida_real             1     0.000008
# nr_ano_partida_real             1     0.000008
# nr_dia_chegada_real             1     0.000008
# nr_semana_partida_real          1     0.000008
# nr_semana_chegada_real          1     0.000008
# nr_ano_mes_chegada_real         1     0.000008
# nm_semestre_chegada_real        1     0.000008
# nm_dia_semana_chegada_real      1     0.000008
# nm_dia_semana_partida_real      1     0.000008
# nm_mes_chegada_real             1     0.000008
# nr_mes_chegada_real             1     0.000008
# nm_trimestre_chegada_real       1     0.000008
# nr_trimestre_chegada_real       1     0.000008
# nr_trimestre_referencia         0     0.000000
# nm_trimestre_referencia         0     0.000000
# nr_mes_referencia               0     0.000000

# %%
# apaga linhas com NaN
df_clean = df.dropna()

# %%
print(f'O dataframe sem NaNs possui {df_clean.shape[0]} linhas e {df_clean.shape[1]} colunas.')
# Out:
# O dataframe sem NaNs possui 118459 linhas e 90 colunas.

# %% [markdown]
# * Cerca de 6% do dataset original foram apagados.

# %%
# lista das empresas presentes no dataset
df_clean['nm_empresa'].unique().tolist()
# Out:
# ['PASSAREDO TRANSPORTES AÉREOS S.A.',
#  'TOTAL LINHAS AÉREAS S.A.',
#  'TWO TÁXI AÉREO LTDA.',
#  'MAP TRANSPORTES AÉREOS LTDA.',
#  'MODERN TRANSPORTE AEREO DE CARGA S.A',
#  'SIDERAL LINHAS AÉREAS LTDA.',
#  'AZUL LINHAS AÉREAS BRASILEIRAS S/A',
#  'TAM LINHAS AÉREAS S.A.',
#  'ASTA LINHAS AÉREAS LTDA ( EX - AMÉRICA DO SUL LINHAS AÉREAS LTDA.)',
#  'ABSA - AEROLINHAS BRASILEIRAS S.A.',
#  'GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS S.A.)']

# %%
# tipo de linha
df_clean['ds_servico_tipo_linha'].unique().tolist()
# Out:
# ['PASSAGEIRO', 'CARGUEIRO']

# %%
# tipo de empresa
df_clean['ds_tipo_empresa'].unique().tolist()
# Out:
# ['TRANSPORTE AÉREO REGULAR',
#  'AEROLEVANTAMENTO, AEROPUBLICIDADE, LIGAÇÃO AÉREA SISTEMÁTICA REGULAR, TÁXI-AÉREO, TRANSPORTE AÉREO REGULAR',
#  'TRANSPORTE AÉREO NÃO REGULAR, TRANSPORTE AÉREO REGULAR',
#  'SERVIÇOS AÉREOS PÚBLICOS, TRANSPORTE AÉREO REGULAR']

# %% [markdown]
# ## 4. Estatística básica
# [Retorna à Tabela de conteúdo](#Tabela-de-conteúdo)

# %%
df_clean[['nr_passag_pagos', 'nr_passag_gratis']].describe()
# Out:
#        nr_passag_pagos  nr_passag_gratis
# count    118459.000000     118459.000000
# mean         47.629509          0.874514
# std          54.525304          1.803593
# min           0.000000          0.000000
# 25%           0.000000          0.000000
# 50%          25.000000          0.000000
# 75%          85.000000          1.000000
# max         351.000000         25.000000

# %% [markdown]
# * Em dezembro de 2020 o total de passageiros foi de 118.459.
#
# * Em média as aeronaves transportaram 48 passageiros pagantes e 1 não pagante.
#
# * A quantidade máxima de passageiros transportada foi de 351 pagantes e 25 não pagantes.

# %%
df_clean[['kg_bagagem_livre', 'kg_bagagem_excesso', 'kg_carga_paga', 'kg_carga_gratis', 'kg_correio']].describe()
# Out:
#        kg_bagagem_livre  kg_bagagem_excesso  kg_carga_paga  kg_carga_gratis  \
# count     118459.000000       118459.000000  118459.000000    118459.000000
# mean         303.421066            4.718612     262.048498         6.313113
# std          404.535047           14.721270    1571.992811        58.965085
# min            0.000000            0.000000       0.000000         0.000000
# 25%            0.000000            0.000000       0.000000         0.000000
# 50%          134.000000            0.000000       0.000000         0.000000
# 75%          482.000000            0.000000      49.000000         0.000000
# max         6391.000000          311.000000   63800.000000      5609.000000
#
#           kg_correio
# count  118459.000000
# mean       46.884542
# std       672.460997
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max     18297.000000

# %%
df_clean['nm_empresa'].astype('object').describe()
# Out:
# count                                                118459
# unique                                                   11
# top       GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS ...
# freq                                                  44727
# Name: nm_empresa, dtype: object

# %% [markdown]
# * Empresa com maior frequência: Gol Linhas Aéreas.

# %% [markdown]
# ## 5. Distribuições
# [Retorna à Tabela de conteúdo](#Tabela-de-conteúdo)

# %%
# boxplot
plt.figure(figsize=(16, 6))
df_clean[['nr_passag_pagos', 'nr_passag_gratis']].boxplot(patch_artist=True, boxprops=dict(facecolor='orange', color='orange'), 
               medianprops=dict(color='red'))
plt.title("Pagantes x Não pagantes", fontsize=20)
plt.show()

# %% [markdown]
# * A quantidade de passageiros pagantes apresenta maior variabilidade/dispersão.
#
# * Entre os pagantes, as viagens concentram-se entre 0 e 85 passageiros.

# %%
f, axes = plt.subplots(1, 2, figsize=(10, 6))
#sns.despine(left=True)

sns.distplot(df_clean['nr_passag_pagos'], ax=axes[0], color="orange")
sns.distplot(df_clean['nr_passag_gratis'], ax=axes[1], color="orange")

#plt.setp(axes, yticks=[])
#plt.setp(axes, xticks=[])
plt.tight_layout()

# %% [markdown]
# * Transporte de poucos passageiros na maior parte das viagens entre pagantes e não pagantes.

# %%
# boxplot
plt.figure(figsize=(16, 10))
df_clean[['kg_bagagem_livre', 'kg_bagagem_excesso', 'kg_carga_paga', 'kg_carga_gratis', 'kg_correio']].boxplot(patch_artist=True, 
            boxprops=dict(facecolor='orange', color='orange'), medianprops=dict(color='red'))
plt.title("Bagagem/Carga x Peso(kg)", fontsize=20)
plt.show()

# %% [markdown]
# * O kg das cargas pagas apresentam a maior variabilidade - fonte de receita direta ou indireta para a empresa aérea.

# %%
f, axes = plt.subplots(3, 2, figsize=(12, 8))
#sns.despine(left=True)

sns.distplot(df_clean['kg_bagagem_livre'], ax=axes[0, 0], color="orange")
sns.distplot(df_clean['kg_bagagem_excesso'], ax=axes[0, 1], kde_kws={'bw': 0.5}, color="orange")
sns.distplot(df_clean['kg_carga_paga'], ax=axes[1, 0], color="orange")
sns.distplot(df_clean['kg_carga_gratis'], ax=axes[1, 1], kde_kws={'bw': 0.5}, color="orange")
sns.distplot(df_clean['kg_correio'], ax=axes[2, 0], kde_kws={'bw': 0.5}, color="orange")

f.delaxes(ax=axes[2, 1])

#plt.setp(axes, yticks=[])
#plt.setp(axes, xticks=[])
plt.tight_layout()

# %% [markdown]
# * Predominância de bagagens dentro do limite.
#
# 💡 Carga paga gera fonte mas possui pouco volume.

# %% [markdown]
# ## 6. Visualizações
# [Retorna à Tabela de conteúdo](#Tabela-de-conteúdo)

# %%
total_empresa = df_clean.groupby(['nm_empresa']).size().reset_index(name='counts').sort_values(by=['counts'], ascending=False)
total_empresa
# Out:
#                                            nm_empresa  counts
# 3   GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS ...   44727
# 8                              TAM LINHAS AÉREAS S.A.   35100
# 2                  AZUL LINHAS AÉREAS BRASILEIRAS S/A   33221
# 10                               TWO TÁXI AÉREO LTDA.    2203
# 6                   PASSAREDO TRANSPORTES AÉREOS S.A.    1427
# 7                         SIDERAL LINHAS AÉREAS LTDA.     948
# 9                            TOTAL LINHAS AÉREAS S.A.     253
# 4                        MAP TRANSPORTES AÉREOS LTDA.     210
# 5                MODERN TRANSPORTE AEREO DE CARGA S.A     189
# 0                  ABSA - AEROLINHAS BRASILEIRAS S.A.     127
# 1   ASTA LINHAS AÉREAS LTDA ( EX - AMÉRICA DO SUL ...      54

# %%
# passageiros pagantes por empresa
fig_dims = (10, 5)
fig, ax = plt.subplots(figsize=fig_dims)

sns.barplot(x='sg_empresa_icao', y='nr_passag_pagos', hue="nm_empresa", dodge=False, data=df_clean)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# * Em número de passageiros pagantes: 1º Azul; 2º TAM; 3º Gol.

# %%
# vôos por empresa
fig_dims = (10, 5)
fig, ax = plt.subplots(figsize=fig_dims)

sns.barplot(x='sg_empresa_icao', y='nr_voo', hue="nm_empresa", dodge=False, data=df_clean)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# * Em número de vôos: 1º Sideral; 2º Map; 3º ABSA.

# %%
# tipo de linha por vôo
fig_dims = (10, 5)
fig, ax = plt.subplots(figsize=fig_dims)

sns.barplot(x='ds_servico_tipo_linha', y='nr_voo', dodge=False, data=df_clean)

# %%
# tipo de empresa
fig_dims = (10, 5)
fig, ax = plt.subplots(figsize=fig_dims)

sns.barplot(x='ds_tipo_empresa', y='nr_voo', hue="ds_tipo_empresa", dodge=False, data=df_clean)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_clean.groupby('sg_empresa_icao').agg({'nr_passag_pagos': ['mean', 'median', 'count', 'std']})
# Out:
#                 nr_passag_pagos
#                            mean median  count        std
# sg_empresa_icao
# AZU                   56.102014   50.0  33221  45.033340
# GLO                   46.281038    8.0  44727  58.433048
# LTG                    0.000000    0.0    127   0.000000
# MWM                    0.000000    0.0    189   0.000000
# OWT                    2.967771    2.0   2203   3.183797
# PAM                   28.176190   32.0    210  13.192444
# PTB                   33.711983   34.0   1427  19.786671
# SID                    1.737342    0.0    948  12.588592
# SUL                    3.444444    2.5     54   3.637678
# TAM                   46.893789   10.0  35100  58.641005
# TTL                    0.000000    0.0    253   0.000000
